# %% [markdown]
# # Python Lecture 8: basic analysis with pandas dataframes
#
# Today we start doing basic data analysis using Python and the **pandas** (panel data) package.
#
# We will use two classes of the `pandas` package: `Series` and `DataFrame`.
#
# #### Series
#
# * Pandas Series contain a column of values together with an index.
# * Instead of the build-in Python data types `Series` objects use datatypes which closer resemble those in C/C++:

# %%
import pandas as pd

a = pd.Series([1.0, 2.1, 3.2, 5.5])
a
# Out:
# 0    1.0
# 1    2.1
# 2    3.2
# 3    5.5
# dtype: float64

# %%
b = pd.Series([1.9, 2.0, 2.1, 2.3], index=[1, 2, 4, 5])
b
# Out:
# 1    1.9
# 2    2.0
# 4    2.1
# 5    2.3
# dtype: float64

# %% [markdown]
# We can calculate with pandas series as follows:

# %%
c = pd.Series([4.0, 3.0, 2.0, 1.0])
print(a + c)
print(c + 2)
print(c ** 2)
# Out:
# 0    5.0
# 1    5.1
# 2    5.2
# 3    6.5
# dtype: float64
# 0    6.0
# 1    5.0
# 2    4.0
# 3    3.0
# dtype: float64
# 0    16.0
# 1     9.0
# 2     4.0
# 3     1.0
# dtype: float64

# %% [markdown]
# Moreover, `Series` support slicing:

# %%
c[1::2]
# Out:
# 1    3.0
# 3    1.0
# dtype: float64

# %% [markdown]
# When adding `Series` objects, the elements are matched according to their index:

# %%
print(b)
print(a + b)
# Out:
# 1    1.9
# 2    2.0
# 4    2.1
# 5    2.3
# dtype: float64
# 0    NaN
# 1    4.0
# 2    5.2
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %% [markdown]
# Here, `NaN` (**N**ot **a** **N**umber) denotes a *missing value*.
#
# `Series` also has useful methods:

# %%
a.sum()
# Out:
# 11.8

# %%
a.min()
# Out:
# 1.0

# %%
a.max()
# Out:
# 5.5

# %%
a.mean()
# Out:
# 2.95

# %% [markdown]
# #### DataFrame
#
# A `DataFrame` is a block of values with named columns. All values in a column have the same type:

# %%
students = pd.DataFrame({'name': ['alex', 'bill', 'chris', 'dave'],
                         'major': ['data science', 'software', 
                                   'software', 'data science'],
                         'score': [1.0, 3.0, 5.0, 2.0]})
students
# Out:
#           major   name  score
# 0  data science   alex    1.0
# 1      software   bill    3.0
# 2      software  chris    5.0
# 3  data science   dave    2.0

# %% [markdown]
# Each column (列）in `DataFrame` is a `Series`, all share the same index. We can select columns using `.`-notation or by their name as an index:

# %%
print(students.name)
print(students['score'])
# Out:
# 0     alex
# 1     bill
# 2    chris
# 3     dave
# Name: name, dtype: object
# 0    1.0
# 1    3.0
# 2    5.0
# 3    2.0
# Name: score, dtype: float64

# %% [markdown]
# Using index notation we can also add new columns:

# %%
students['passed'] = students['score'] < 5
students
# Out:
#           major   name  score passed
# 0  data science   alex    1.0   True
# 1      software   bill    3.0   True
# 2      software  chris    5.0  False
# 3  data science   dave    2.0   True

# %% [markdown]
# We can select rows in a DataFrame by passing a series of truth values:

# %%
passed = students[students.passed]
passed
# Out:
#           major  name  score passed
# 0  data science  alex    1.0   True
# 1      software  bill    3.0   True
# 3  data science  dave    2.0   True

# %%
good_students = students[students.score < 2.5]
good_students
# Out:
#           major  name  score passed
# 0  data science  alex    1.0   True
# 3  data science  dave    2.0   True

# %%
students[ [True, False, True, False] ]
# Out:
#           major   name  score passed
# 0  data science   alex    1.0   True
# 2      software  chris    5.0  False

# %% [markdown]
# #### Exercise:
# Calculate the average score over all students:

# %%
students['score'].mean()
# Out:
# 2.75

# %% [markdown]
# Add a column `good` to the DataFrame which is `True` is the student's score is less
# than the average score and `False` otherwise.

# %%
students['good'] = students['score'] < students['score'].mean()
students
# Out:
#           major   name  score passed   good
# 0  data science   alex    1.0   True   True
# 1      software   bill    3.0   True  False
# 2      software  chris    5.0  False  False
# 3  data science   dave    2.0   True   True

# %% [markdown]
# ## DataFrames and SQL
#
# `select score from students` = `students['score']`
#
# ```
# select * from students
#     where score < 2.5
# ```
#
# ```
# students[students['score'] < 2.5]
# ```
#
#
# ```
# select major, avg(score) from students group by major
# ```

# %% [markdown]
# ### Grouping data
#
# We often need to divide our data into groups and then will combine the data in each group.
#
# DataFrames provide us with the `groupby` method to do just this.
#
# For example, let us calculate the average score for each major:

# %%
students.groupby('major').mean()
# Out:
#               score  passed  good
# major
# data science    1.5     1.0   1.0
# software        4.0     0.5   0.0

# %% [markdown]
# In fact we also have calculated the fraction of students which passed.
#
# ### Now let us have a look at the questions from last exercise
#
# We can use `pd.read_csv` to open a csv file and read it into a DataFrame:

# %%
titanic_df = pd.read_csv('titanic.csv')
titanic_df.head(12)
# Out:
#     survived  pclass                                               name  \
# 0          1       1                      Allen, Miss. Elisabeth Walton
# 1          1       1                     Allison, Master. Hudson Trevor
# 2          0       1                       Allison, Miss. Helen Loraine
# 3          0       1               Allison, Mr. Hudson Joshua Creighton
# 4          0       1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1       1                                Anderson, Mr. Harry
# 6          1       1                  Andrews, Miss. Kornelia Theodosia
# 7          0       1                             Andrews, Mr. Thomas Jr
# 8          1       1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          0       1                            Artagaveytia, Mr. Ramon
# 10         0       1                             Astor, Col. John Jacob
# 11         1       1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
#
#        sex      age  sibsp  parch    ticket      fare
# 0   female  29.0000      0      0     24160  211.3375
# 1     male   0.9167      1      2    113781  151.5500
# 2   female   2.0000      1      2    113781  151.5500
# 3     male  30.0000      1      2    113781  151.5500
# 4   female  25.0000      1      2    113781  151.5500
# 5     male  48.0000      0      0     19952   26.5500
# 6   female  63.0000      1      0     13502   77.9583
# 7     male  39.0000      0      0    112050    0.0000
# 8   female  53.0000      2      0     11769   51.4792
# 9     male  71.0000      0      0  PC 17609   49.5042
# 10    male  47.0000      1      0  PC 17757  227.5250
# 11  female  18.0000      1      0  PC 17757  227.5250

# %% [markdown]
# The `head` function shows us the first couple of rows in a DataFrame.
#
# Now let's have a look at the problems from last week:
#
# **Calculate how many males and females were on board of the Titanic:**

# %%
titanic_df.groupby('sex').size()
# Out:
# sex
# female    466
# male      843
# dtype: int64

# %% [markdown]
# **Calculate how many passengers were in each passenger class (pclass) and calculate the average fare for each passenger class:**

# %%
print(titanic_df.groupby('pclass').size())

titanic_df.groupby('pclass').mean()
# Out:
# pclass
# 1    323
# 2    277
# 3    709
# dtype: int64
#         survived        age     sibsp     parch       fare
# pclass
# 1       0.619195  34.431631  0.436533  0.365325  87.508992
# 2       0.429603  27.802347  0.393502  0.368231  21.179196
# 3       0.255289  17.535966  0.568406  0.400564  13.295262

# %% [markdown]
# We can solve both problems in one step using the `agg` function. It expects a dictionary whose keys are the column names and whose values are the functions names:

# %%
titanic_df.groupby('pclass').agg({
    'fare': 'mean',
    'pclass': 'size'
})
# Out:
#              fare  pclass
# pclass
# 1       87.508992     323
# 2       21.179196     277
# 3       13.295262     709

# %% [markdown]
# **For each of the age groups: 0-6, 7-12, 13-18, 18-60, 61-100 calculate how many passengers where in this age group and how many passengers of this age group survived.**

# %%
def age_group(age):
    age = float(age)
    if age < 7:
        return "0-6"
    if age < 13:
        return "7-12"
    if age < 18:
        return "13-18"
    if age <= 60:
        return "18-60"
    return "61-100"

titanic_df['ag'] = titanic_df.age.apply(age_group) 
titanic_df.groupby('ag').agg({
    'survived': 'mean',
    'ag': 'size'
})
# Out:
#         survived   ag
# ag
# 0-6     0.347692  325
# 13-18   0.450000   60
# 18-60   0.393481  859
# 61-100  0.242424   33
# 7-12    0.437500   32

# %% [markdown]
# The `apply` function is similar to `map` for list:

# %%
titanic_df
# Out:
#       survived  pclass                                               name  \
# 0            1       1                      Allen, Miss. Elisabeth Walton
# 1            1       1                     Allison, Master. Hudson Trevor
# 2            0       1                       Allison, Miss. Helen Loraine
# 3            0       1               Allison, Mr. Hudson Joshua Creighton
# 4            0       1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5            1       1                                Anderson, Mr. Harry
# 6            1       1                  Andrews, Miss. Kornelia Theodosia
# 7            0       1                             Andrews, Mr. Thomas Jr
# 8            1       1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9            0       1                            Artagaveytia, Mr. Ramon
# 10           0       1                             Astor, Col. John Jacob
# 11           1       1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12           1       1                      Aubart, Mme. Leontine Pauline
# 13           1       1                       Barber, Miss. Ellen "Nellie"
# 14           1       1               Barkworth, Mr. Algernon Henry Wilson
# 15           0       1                                Baumann, Mr. John D
# 16           0       1                           Baxter, Mr. Quigg Edmond
# 17           1       1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18           1       1                              Bazzani, Miss. Albina
# 19           0       1                               Beattie, Mr. Thomson
# 20           1       1                      Beckwith, Mr. Richard Leonard
# 21           1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22           1       1                              Behr, Mr. Karl Howell
# 23           1       1                              Bidois, Miss. Rosalie
# 24           1       1                                  Bird, Miss. Ellen
# 25           0       1                                Birnbaum, Mr. Jakob
# 26           1       1                            Bishop, Mr. Dickinson H
# 27           1       1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28           1       1                             Bissette, Miss. Amelia
# 29           1       1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# ...        ...     ...                                                ...
# 1279         0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 1280         0       3                                    Vovk, Mr. Janko
# 1281         0       3                               Waelens, Mr. Achille
# 1282         0       3                                Ware, Mr. Frederick
# 1283         0       3                        Warren, Mr. Charles William
# 1284         0       3                                  Webber, Mr. James
# 1285         0       3                                Wenzel, Mr. Linhart
# 1286         1       3    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287         0       3                   Widegren, Mr. Carl/Charles Peter
# 1288         0       3                          Wiklund, Mr. Jakob Alfred
# 1289         0       3                            Wiklund, Mr. Karl Johan
# 1290         1       3                   Wilkes, Mrs. James (Ellen Needs)
# 1291         0       3                   Willer, Mr. Aaron ("Abi Weller")
# 1292         0       3                                 Willey, Mr. Edward
# 1293         0       3                  Williams, Mr. Howard Hugh "Harry"
# 1294         0       3                               Williams, Mr. Leslie
# 1295         0       3                                Windelov, Mr. Einar
# 1296         0       3                                   Wirz, Mr. Albert
# 1297         0       3                             Wiseman, Mr. Phillippe
# 1298         0       3                          Wittevrongel, Mr. Camille
# 1299         0       3                                Yasbeck, Mr. Antoni
# 1300         1       3            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301         0       3                               Youseff, Mr. Gerious
# 1302         0       3                                  Yousif, Mr. Wazli
# 1303         0       3                              Yousseff, Mr. Gerious
# 1304         0       3                               Zabour, Miss. Hileni
# 1305         0       3                              Zabour, Miss. Thamine
# 1306         0       3                          Zakarian, Mr. Mapriededer
# 1307         0       3                                Zakarian, Mr. Ortin
# 1308         0       3                                 Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch            ticket      fare      ag
# 0     female  29.0000      0      0             24160  211.3375   18-60
# 1       male   0.9167      1      2            113781  151.5500     0-6
# 2     female   2.0000      1      2            113781  151.5500     0-6
# 3       male  30.0000      1      2            113781  151.5500   18-60
# 4     female  25.0000      1      2            113781  151.5500   18-60
# 5       male  48.0000      0      0             19952   26.5500   18-60
# 6     female  63.0000      1      0             13502   77.9583  61-100
# 7       male  39.0000      0      0            112050    0.0000   18-60
# 8     female  53.0000      2      0             11769   51.4792   18-60
# 9       male  71.0000      0      0          PC 17609   49.5042  61-100
# 10      male  47.0000      1      0          PC 17757  227.5250   18-60
# 11    female  18.0000      1      0          PC 17757  227.5250   18-60
# 12    female  24.0000      0      0          PC 17477   69.3000   18-60
# 13    female  26.0000      0      0             19877   78.8500   18-60
# 14      male  80.0000      0      0             27042   30.0000  61-100
# 15      male   0.0000      0      0          PC 17318   25.9250     0-6
# 16      male  24.0000      0      1          PC 17558  247.5208   18-60
# 17    female  50.0000      0      1          PC 17558  247.5208   18-60
# 18    female  32.0000      0      0             11813   76.2917   18-60
# 19      male  36.0000      0      0             13050   75.2417   18-60
# 20      male  37.0000      1      1             11751   52.5542   18-60
# 21    female  47.0000      1      1             11751   52.5542   18-60
# 22      male  26.0000      0      0            111369   30.0000   18-60
# 23    female  42.0000      0      0          PC 17757  227.5250   18-60
# 24    female  29.0000      0      0          PC 17483  221.7792   18-60
# 25      male  25.0000      0      0             13905   26.0000   18-60
# 26      male  25.0000      1      0             11967   91.0792   18-60
# 27    female  19.0000      1      0             11967   91.0792   18-60
# 28    female  35.0000      0      0          PC 17760  135.6333   18-60
# 29      male  28.0000      0      0            110564   26.5500   18-60
# ...      ...      ...    ...    ...               ...       ...     ...
# 1279  female  14.0000      0      0            350406    7.8542   13-18
# 1280    male  22.0000      0      0            349252    7.8958   18-60
# 1281    male  22.0000      0      0            345767    9.0000   18-60
# 1282    male   0.0000      0      0            359309    8.0500     0-6
# 1283    male   0.0000      0      0        C.A. 49867    7.5500     0-6
# 1284    male   0.0000      0      0  SOTON/OQ 3101316    8.0500     0-6
# 1285    male  32.5000      0      0            345775    9.5000   18-60
# 1286  female  38.0000      0      0              2688    7.2292   18-60
# 1287    male  51.0000      0      0            347064    7.7500   18-60
# 1288    male  18.0000      1      0           3101267    6.4958   18-60
# 1289    male  21.0000      1      0           3101266    6.4958   18-60
# 1290  female  47.0000      1      0            363272    7.0000   18-60
# 1291    male   0.0000      0      0              3410    8.7125     0-6
# 1292    male   0.0000      0      0     S.O./P.P. 751    7.5500     0-6
# 1293    male   0.0000      0      0          A/5 2466    8.0500     0-6
# 1294    male  28.5000      0      0             54636   16.1000   18-60
# 1295    male  21.0000      0      0  SOTON/OQ 3101317    7.2500   18-60
# 1296    male  27.0000      0      0            315154    8.6625   18-60
# 1297    male   0.0000      0      0        A/4. 34244    7.2500     0-6
# 1298    male  36.0000      0      0            345771    9.5000   18-60
# 1299    male  27.0000      1      0              2659   14.4542   18-60
# 1300  female  15.0000      1      0              2659   14.4542   13-18
# 1301    male  45.5000      0      0              2628    7.2250   18-60
# 1302    male   0.0000      0      0              2647    7.2250     0-6
# 1303    male   0.0000      0      0              2627   14.4583     0-6
# 1304  female  14.5000      1      0              2665   14.4542   13-18
# 1305  female   0.0000      1      0              2665   14.4542     0-6
# 1306    male  26.5000      0      0              2656    7.2250   18-60
# 1307    male  27.0000      0      0              2670    7.2250   18-60
# 1308    male  29.0000      0      0            315082    7.8750   18-60
#
# [1309 rows x 10 columns]

# %% [markdown]
# **For each combination of sex and pclass calculate the change of survival.**

# %%
titanic_df.groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age     sibsp     parch        fare
# sex    pclass
# female 1       0.965278  34.208333  0.555556  0.472222  109.412385
#        2       0.886792  26.720912  0.500000  0.650943   23.234827
#        3       0.490741  15.611883  0.791667  0.731481   15.324250
# male   1       0.340782  34.611266  0.340782  0.279330   69.888385
#        2       0.146199  28.472709  0.327485  0.192982   19.904946
#        3       0.152130  18.378972  0.470588  0.255578   12.406294

# %% [markdown]
# **Add a column `is_child` to the dataframe calculate the chance of survival for each combination of sex, pclass, and is_child:**

# %%
titanic_df['is_child'] = titanic_df['age'] < 18
titanic_df.groupby(['pclass', 'sex', 'is_child']).mean()
# Out:
#                         survived        age     sibsp     parch        fare
# pclass sex    is_child
# 1      female False     0.968000  38.504000  0.560000  0.480000  112.503368
#               True      0.947368   5.947368  0.526316  0.421053   89.076968
#        male   False     0.326389  42.545139  0.395833  0.263889   72.147802
#               True      0.400000   1.969049  0.114286  0.342857   60.592497
# 2      female False     0.870588  31.570588  0.482353  0.564706   22.265441
#               True      0.952381   7.091271  0.571429  1.000000   27.158533
#        male   False     0.083916  33.395105  0.328671  0.132867   19.799795
#               True      0.464286   3.333332  0.321429  0.500000   20.441964
# 3      female False     0.443396  28.160377  0.424528  0.688679   13.081174
#               True      0.536364   3.519697  1.145455  0.772727   17.485759
#        male   False     0.155709  29.309689  0.179931  0.134948   10.101093
#               True      0.147059   2.893791  0.882353  0.426471   15.671996

# %%
surv = titanic_df.groupby(['pclass', 'sex', 'is_child']).mean()
surv
# Out:
#                         survived        age     sibsp     parch        fare
# pclass sex    is_child
# 1      female False     0.968000  38.504000  0.560000  0.480000  112.503368
#               True      0.947368   5.947368  0.526316  0.421053   89.076968
#        male   False     0.326389  42.545139  0.395833  0.263889   72.147802
#               True      0.400000   1.969049  0.114286  0.342857   60.592497
# 2      female False     0.870588  31.570588  0.482353  0.564706   22.265441
#               True      0.952381   7.091271  0.571429  1.000000   27.158533
#        male   False     0.083916  33.395105  0.328671  0.132867   19.799795
#               True      0.464286   3.333332  0.321429  0.500000   20.441964
# 3      female False     0.443396  28.160377  0.424528  0.688679   13.081174
#               True      0.536364   3.519697  1.145455  0.772727   17.485759
#        male   False     0.155709  29.309689  0.179931  0.134948   10.101093
#               True      0.147059   2.893791  0.882353  0.426471   15.671996

# %% [markdown]
# ### Another example
#
# Let's analyze some sales data:

# %%
sales=pd.read_csv("sample-sales-20.csv",parse_dates=['date'])
sales.head()
# Out:
#    account number                           name       sku category  quantity  \
# 0          296809                    Carroll PLC  QN-82852     Belt        13
# 1           98022              Heidenreich-Bosco  MJ-21460    Shoes        19
# 2          563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12
# 3           93356                  Waters-Walker  AS-93055    Shirt         5
# 4          659366                  Waelchi-Fahey  AS-93055    Shirt        18
#
#    unit price  ext price                date
# 0       44.48     578.24 2014-09-27 07:13:03
# 1       53.62    1018.78 2014-07-29 02:10:44
# 2       24.16     289.92 2014-03-01 10:51:24
# 3       82.68     413.40 2013-11-17 20:41:11
# 4       99.64    1793.52 2014-01-03 08:14:27

# %% [markdown]
# Using the `describe` method we can do some simple analysis:

# %%
sales.describe()
# Out:
#        account number     quantity   unit price   ext price
# count     1000.000000  1000.000000  1000.000000  1000.00000
# mean    535208.897000    10.328000    56.179630   579.84390
# std     277589.746014     5.687597    25.331939   435.30381
# min      93356.000000     1.000000    10.060000    10.38000
# 25%     299771.000000     5.750000    35.995000   232.60500
# 50%     563905.000000    10.000000    56.765000   471.72000
# 75%     750461.000000    15.000000    76.802500   878.13750
# max     995267.000000    20.000000    99.970000  1994.80000

# %% [markdown]
# We can use index notation to get the values of a single column:

# %%
sales['unit price'].describe()
# Out:
# count    1000.000000
# mean       56.179630
# std        25.331939
# min        10.060000
# 25%        35.995000
# 50%        56.765000
# 75%        76.802500
# max        99.970000
# Name: unit price, dtype: float64

# %% [markdown]
# ``dtypes`` describes the datatypes in a dataframe:

# %%
sales.dtypes
# Out:
# account number             int64
# name                      object
# sku                       object
# category                  object
# quantity                   int64
# unit price               float64
# ext price                float64
# date              datetime64[ns]
# dtype: object

# %% [markdown]
# Let us remove some columns to simplify our analysis:

# %%
customers = sales[['name','ext price','date']]
customers.head()
# Out:
#                             name  ext price                date
# 0                    Carroll PLC     578.24 2014-09-27 07:13:03
# 1              Heidenreich-Bosco    1018.78 2014-07-29 02:10:44
# 2  Kerluke, Reilly and Bechtelar     289.92 2014-03-01 10:51:24
# 3                  Waters-Walker     413.40 2013-11-17 20:41:11
# 4                  Waelchi-Fahey    1793.52 2014-01-03 08:14:27

# %% [markdown]
# Each line in the dataframe is still for one order. Let us group the orders by customers and see how many orders each customer has done:

# %%
customer_group = customers.groupby('name')
customer_group.size()
# Out:
# name
# Berge LLC                        52
# Carroll PLC                      57
# Cole-Eichmann                    51
# Davis, Kshlerin and Reilly       41
# Ernser, Cruickshank and Lind     47
# Gorczany-Hahn                    42
# Hamill-Hackett                   44
# Hegmann and Sons                 58
# Heidenreich-Bosco                40
# Huel-Haag                        43
# Kerluke, Reilly and Bechtelar    52
# Kihn, McClure and Denesik        58
# Kilback-Gerlach                  45
# Koelpin PLC                      53
# Kunze Inc                        54
# Kuphal, Zieme and Kub            52
# Senger, Upton and Breitenberg    59
# Volkman, Goyette and Lemke       48
# Waelchi-Fahey                    54
# Waters-Walker                    50
# dtype: int64

# %% [markdown]
# Let us now sum up the total values of each customer. This can be done using ``sum()``. We then sort he values and print the first 5:

# %%
sales_totals = customer_group.sum()
sales_totals.sort_values(by='ext price').head()
# Out:
#                             ext price
# name
# Davis, Kshlerin and Reilly   19054.76
# Huel-Haag                    21087.88
# Gorczany-Hahn                22207.90
# Hamill-Hackett               23433.78
# Heidenreich-Bosco            25428.29

# %% [markdown]
# We might be more interested in who our best customers are:

# %%
sales_totals.sort_values(by='ext price', ascending=False).head()
# Out:
#                            ext price
# name
# Kihn, McClure and Denesik   38935.29
# Waters-Walker               36778.96
# Carroll PLC                 35934.31
# Hegmann and Sons            35213.72
# Kunze Inc                   34406.54

# %% [markdown]
# ## Another Example
#
# ### Preparation: making some random data
#
# We use the `random` package to generate some random data:

# %%
import random

names = ['Fred', 'Peter', 'Bill', 
        'Sammy', 'Tom', 'Sarah', 'Anthony', 'Barny', 'Philip', 'Zach',
        'Betty', 'Chris', 'Sarah', 'Tim', 'Dick', 'Donald', 'Angela']
genders = ['male', 'male', 'male', 
           'male', 'male', 'female', 'male', 'male', 'male', 'male',
          'female', 'male', 'female', 'male', 'male', 'male' ,'female']
majors = ['software', 'management', 'finance']

random.seed(42) #to get same values each time we run the code

header = "name,gender,major,year,q1,q2,q3,q4,q5,q6,hw1,hw2,hw3,exam\n"

with open('grades_new.csv', 'w', encoding='utf-8') as file:
    file.write(header)
    for name, gender in zip(names, genders):
        data = [name, gender, random.choice(majors), str(random.randint(2014, 2017))]
        grades = [str(random.randint(25, 100)) for i in range(10)]
        s = ','.join(data + grades) + "\n"
        file.write(s)

# %% [markdown]
# ### Opening the data using pandas:

# %%
df = pd.read_csv('grades_new.csv')
df
# Out:
#        name  gender       major  year   q1  q2  q3   q4  q5  q6  hw1  hw2  \
# 0      Fred    male     finance  2014   28  60  56   53  42  38   94   36
# 1     Peter    male    software  2014   36  52  54   89  28  96   50   94
# 2      Bill    male  management  2016   25  45  79   68  60  44   52   68
# 3     Sammy    male  management  2014   70  69  58   30  83  93   40   73
# 4       Tom    male  management  2016   98  49  33   30  54  62   35   54
# 5     Sarah  female  management  2017   71  45  72   70  51  59   34   46
# 6   Anthony    male    software  2017   73  59  96   53  66  32   54   29
# 7     Barny    male  management  2014   52  97  65   52  88  75   83   43
# 8    Philip    male    software  2016   99  79  99   76  71  53   42   90
# 9      Zach    male    software  2014   44  45  79   33  74  73   84   92
# 10    Betty  female    software  2014   93  59  68   39  62  80   45   83
# 11    Chris    male     finance  2015   89  38  63   89  50  44   72   45
# 12    Sarah  female    software  2016   87  27  39   71  64  55   32   55
# 13      Tim    male    software  2017   33  93  41   41  85  95   46   58
# 14     Dick    male    software  2015   64  76  72   81  91  82   40   56
# 15   Donald    male  management  2014  100  95  54  100  53  25   34   32
# 16   Angela  female    software  2016   34  90  55   60  87  52   94   41
#
#     hw3  exam
# 0   100    79
# 1    78    53
# 2    38    36
# 3    35    95
# 4    37    73
# 5    93    56
# 6    65    76
# 7    58    42
# 8    88    36
# 9    57    95
# 10   25    58
# 11   94    92
# 12   97    35
# 13   92    79
# 14   53    33
# 15   54    33
# 16   98    98

# %% [markdown]
# Now add a columns which contain the average quiz and homework grades:

# %%
#calculate average quiz grade:
df['avg_q'] = (df['q1'] + df['q2'] + df['q3'] + df['q4'] + df['q5'] + df['q6']) /6
df.head()
# Out:
#     name gender       major  year  q1  q2  q3  q4  q5  q6  hw1  hw2  hw3  \
# 0   Fred   male     finance  2014  28  60  56  53  42  38   94   36  100
# 1  Peter   male    software  2014  36  52  54  89  28  96   50   94   78
# 2   Bill   male  management  2016  25  45  79  68  60  44   52   68   38
# 3  Sammy   male  management  2014  70  69  58  30  83  93   40   73   35
# 4    Tom   male  management  2016  98  49  33  30  54  62   35   54   37
#
#    exam      avg_q
# 0    79  46.166667
# 1    53  59.166667
# 2    36  53.500000
# 3    95  67.166667
# 4    73  54.333333

# %%
df['avg_q'] = df.loc[:, 'q1':'q6'].mean(axis=1)
df['avg_hw'] = df.loc[:, 'hw1':'hw3'].mean(axis=1)

# %%
df['final'] =  df[['avg_q', 'avg_hw', 'exam']].mean(axis=1)

# %%
df['passed'] = df['final'] >= 60
df.groupby(['major', 'passed']).size()
# Out:
# major       passed
# finance     True      2
# management  False     5
#             True      1
# software    False     3
#             True      6
# dtype: int64

# %%
df
# Out:
#        name  gender       major  year   q1  q2  q3   q4  q5  q6  hw1  hw2  \
# 0      Fred    male     finance  2014   28  60  56   53  42  38   94   36
# 1     Peter    male    software  2014   36  52  54   89  28  96   50   94
# 2      Bill    male  management  2016   25  45  79   68  60  44   52   68
# 3     Sammy    male  management  2014   70  69  58   30  83  93   40   73
# 4       Tom    male  management  2016   98  49  33   30  54  62   35   54
# 5     Sarah  female  management  2017   71  45  72   70  51  59   34   46
# 6   Anthony    male    software  2017   73  59  96   53  66  32   54   29
# 7     Barny    male  management  2014   52  97  65   52  88  75   83   43
# 8    Philip    male    software  2016   99  79  99   76  71  53   42   90
# 9      Zach    male    software  2014   44  45  79   33  74  73   84   92
# 10    Betty  female    software  2014   93  59  68   39  62  80   45   83
# 11    Chris    male     finance  2015   89  38  63   89  50  44   72   45
# 12    Sarah  female    software  2016   87  27  39   71  64  55   32   55
# 13      Tim    male    software  2017   33  93  41   41  85  95   46   58
# 14     Dick    male    software  2015   64  76  72   81  91  82   40   56
# 15   Donald    male  management  2014  100  95  54  100  53  25   34   32
# 16   Angela  female    software  2016   34  90  55   60  87  52   94   41
#
#     hw3  exam      avg_q     avg_hw      final passed
# 0   100    79  46.166667  76.666667  67.277778   True
# 1    78    53  59.166667  74.000000  62.055556   True
# 2    38    36  53.500000  52.666667  47.388889  False
# 3    35    95  67.166667  49.333333  70.500000   True
# 4    37    73  54.333333  42.000000  56.444444  False
# 5    93    56  61.333333  57.666667  58.333333  False
# 6    65    76  63.166667  49.333333  62.833333   True
# 7    58    42  71.500000  61.333333  58.277778  False
# 8    88    36  79.500000  73.333333  62.944444   True
# 9    57    95  58.000000  77.666667  76.888889   True
# 10   25    58  66.833333  51.000000  58.611111  False
# 11   94    92  62.166667  70.333333  74.833333   True
# 12   97    35  57.166667  61.333333  51.166667  False
# 13   92    79  64.666667  65.333333  69.666667   True
# 14   53    33  77.666667  49.666667  53.444444  False
# 15   54    33  71.166667  40.000000  48.055556  False
# 16   98    98  63.000000  77.666667  79.555556   True

# %%
finals = df[['name', 'gender', 'major', 'year', 'final', 'passed']]

# %%
finals.to_excel('finals.xls')

# %%
df2 = pd.read_excel('finals.xls')

# %%
for x in df2:
    print(x)
# Out:
# name
# gender
# major
# year
# final
# passed
